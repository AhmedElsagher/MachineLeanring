# %% [markdown]
# # Fire Up

# %%
import graphlab

# %% [markdown]
# ## Load Data

# %%
sf=graphlab.SFrame('home_data.gl/home_data.gl/')

# %%
sf.column_names()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# ## explore data

# %%
graphlab.canvas.set_target('ipynb')
sf.show(view='Scatter Plot',x='sqft_living',y='price')

# %% [markdown]
# ## create simple Reg Model

# %%
train_data,test_data=sf.random_split(.8,seed=0)

# %% [markdown]
# ## build Reg Model
